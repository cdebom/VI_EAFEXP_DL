# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

from tqdm import tqdm, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import concatenate, add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras import backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
WORK_DIR = '/content/drive/MyDrive/PosDoc/O2I/Dados_Kaggle/'
## conjunto reduzido, carga mais rápida
DATA_IMAGES = '/content/drive/MyDrive/PosDoc/O2I/Dados_Kaggle/train/images'
DATA_MASKS = '/content/drive/MyDrive/PosDoc/O2I/Dados_Kaggle/train/masks'
## conjunto completo com 4000 modelos
# DATA_IMAGES = '/content/drive/MyDrive/PosDoc/O2I/Dados_Kaggle/train2/images'
# DATA_MASKS = '/content/drive/MyDrive/PosDoc/O2I/Dados_Kaggle/train2/masks'

# %%
## Config
IM_HEIGHT = 128
IM_WIDTH = 128
IMG_IDS = next(os.walk(DATA_IMAGES))[2]
print("---"*20)
print(f"No of images in the dataset: {len(IMG_IDS)}")
print("---"*20)
# Out:
# ------------------------------------------------------------
# No of images in the dataset: 1960
# ------------------------------------------------------------

# %%
## Get empty numpy arrays
X = np.zeros((len(IMG_IDS), IM_HEIGHT, IM_WIDTH, 1), dtype=np.float32)
y = np.zeros((len(IMG_IDS), IM_HEIGHT, IM_WIDTH, 1), dtype=np.float32)

# %%
def create_labelled_dataset():
   
    for n, ids in enumerate(tqdm(IMG_IDS)):        
        img = load_img(os.path.join(DATA_IMAGES, ids))
        x_img_arr = np.asarray((img))
        x_img = resize(x_img_arr, (IM_HEIGHT, IM_WIDTH, 1), mode='constant', preserve_range=True)
        
        mask  = load_img(os.path.join(DATA_MASKS, ids))
        y_mask_arr = np.asarray(mask)
        y_mask = resize(y_mask_arr, (IM_HEIGHT, IM_WIDTH, 1), mode='constant', preserve_range=True)
        
        X[n] = x_img/255.0 
        y[n] = y_mask/255.0
        
    return X, y

# %%
X, y = create_labelled_dataset()
# Out:
# 100%|██████████| 1960/1960 [12:01<00:00,  2.71it/s]

# %%
## Train and Validation set
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
## Plotting Sample Data

def plot_sample_example():
    ix = random.randint(0, len(X_train))
    print(f"Random Sample Index is: {ix}")
    has_mask = y_train[ix].max() > 0

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 10))

    ax1.imshow(X_train[ix, ..., 0], cmap = 'gray', interpolation = 'bilinear')

    ## If there is a mask
    if has_mask:
        ax1.contour(y_train[ix].squeeze(), colors = 'black', linewidths = 3, levels = [0.5])
    ax1.set_title('Seismic')

    ax2.imshow(y_train[ix].squeeze(), cmap = 'gray', interpolation = 'bilinear')
    ax2.set_title('Salt')
    
plot_sample_example()
# Out:
# Random Sample Index is: 739

# %%
## 2D two Convolution layer block
def Conv2D_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    """Function to add 2 convolutional layers"""
    ## Convolution layer - 1
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), \
              kernel_initializer='he_normal', padding='same')(input_tensor)
    ## batchnormalization
    if batchnorm:
        x = BatchNormalization()(x)
    ## Activation
    x = Activation('relu')(x)
        
    ## Convolution layer - 2
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), \
               kernel_initializer='he_normal', padding='same')(x)
    ## batchnormalization
    if batchnorm:
        x = BatchNormalization()(x)
    ## Activation
    x = Activation('relu')(x)
    
    return x

# %%
## Unet Architecture
def unet(input_image, n_filters=16, kernel_size=3, dropout=0.1, batchnorm=True):
    ## Encoder Path || Contractor Path
    c1 = Conv2D_block(input_image, n_filters, kernel_size = kernel_size, batchnorm = batchnorm)
    p1 = MaxPooling2D((2,2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = Conv2D_block(p1, n_filters * 2, kernel_size = kernel_size, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = Conv2D_block(p2, n_filters * 4, kernel_size = kernel_size, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = Conv2D_block(p3, n_filters * 8, kernel_size = kernel_size, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = Conv2D_block(p4, n_filters * 16, kernel_size = kernel_size, batchnorm = batchnorm)
    
    ## Decoder Path  || Expansion Path
    u6 = Conv2DTranspose(n_filters * 8, (kernel_size, kernel_size), strides=(2,2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = Conv2D_block(u6, n_filters * 8, kernel_size = kernel_size, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (kernel_size, kernel_size), strides=(2,2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = Conv2D_block(u7, n_filters * 4, kernel_size = kernel_size, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (kernel_size, kernel_size), strides=(2,2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = Conv2D_block(u8, n_filters * 2, kernel_size = kernel_size, batchnorm = batchnorm)
   
    u9 = Conv2DTranspose(n_filters, (kernel_size, kernel_size), strides=(2,2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = Conv2D_block(u9, n_filters, kernel_size = kernel_size, batchnorm = batchnorm)
   
    ## final 1*1 Convolutional layer
    output = Conv2D(1, (1,1), activation='sigmoid')(c9)
    model = Model(inputs=[input_image], outputs=[output])
    return model

# %%
def jaccard_distance_loss(y_true, y_pred, smooth=100):
    """
    Jaccard = (|X & Y|)/ (|X|+ |Y| - |X & Y|)
            = sum(|A*B|)/(sum(|A|)+sum(|B|)-sum(|A*B|))
    
    The jaccard distance loss is usefull for unbalanced datasets. This has been
    shifted so it converges on 0 and is smoothed to avoid exploding or disapearing
    gradient.
    
    Ref: https://en.wikipedia.org/wiki/Jaccard_index
    
    @url: https://gist.github.com/wassname/f1452b748efcbeb4cb9b1d059dce6f96
    @author: wassname
    """
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

# %%
## Instantiate Keras tensor
input_img = Input((IM_HEIGHT, IM_WIDTH, 1), name='img')
model = unet(input_img, n_filters=16, kernel_size=3, dropout=0.05, batchnorm=True)
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=["accuracy"])
# model.compile(optimizer=Adam(), loss=jaccard_distance_loss, metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 16  160         ['img[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 16)  0           ['activation_19[0][0]']
#
#  dropout_8 (Dropout)            (None, 64, 64, 16)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 32)   4640        ['dropout_8[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_21[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_21[0][0]']
#
#  dropout_9 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 64)   18496       ['dropout_9[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_23[0][0]']
#
#  dropout_10 (Dropout)           (None, 16, 16, 64)   0           ['max_pooling2d_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 128)  73856       ['dropout_10[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_25[0][0]']
#
#  dropout_11 (Dropout)           (None, 8, 8, 128)    0           ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 256)    295168      ['dropout_11[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 256)    590080      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 128)  295040     ['activation_27[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'activation_25[0][0]']
#
#  dropout_12 (Dropout)           (None, 16, 16, 256)  0           ['concatenate_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_12[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_29[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_23[0][0]']
#
#  dropout_13 (Dropout)           (None, 32, 32, 128)  0           ['concatenate_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 32)  18464       ['activation_31[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_6[0][0]',
#                                                                   'activation_21[0][0]']
#
#  dropout_14 (Dropout)           (None, 64, 64, 64)   0           ['concatenate_6[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_14[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 16  4624       ['activation_33[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'activation_19[0][0]']
#
#  dropout_15 (Dropout)           (None, 128, 128, 32  0           ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_15[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 16  64         ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 16  2320        ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 16  64         ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 1)  17          ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 2,164,305
# Trainable params: 2,161,361
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
## Call Backs
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(X_train, y_train, batch_size=32, epochs=50, callbacks=callbacks, \
                   validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.4620 - accuracy: 0.6568
# Epoch 1: val_loss improved from inf to 0.81163, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 9s 111ms/step - loss: 0.4617 - accuracy: 0.6568 - val_loss: 0.8116 - val_accuracy: 0.4570 - lr: 0.0010
# Epoch 2/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3499 - accuracy: 0.7098
# Epoch 2: val_loss did not improve from 0.81163
# 56/56 [==============================] - 6s 101ms/step - loss: 0.3501 - accuracy: 0.7095 - val_loss: 4.0009 - val_accuracy: 0.2124 - lr: 0.0010
# Epoch 3/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3142 - accuracy: 0.7205
# Epoch 3: val_loss did not improve from 0.81163
# 56/56 [==============================] - 6s 103ms/step - loss: 0.3140 - accuracy: 0.7205 - val_loss: 3.2774 - val_accuracy: 0.0288 - lr: 0.0010
# Epoch 4/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2954 - accuracy: 0.7251
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 4: val_loss did not improve from 0.81163
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2951 - accuracy: 0.7251 - val_loss: 1.6315 - val_accuracy: 0.4102 - lr: 0.0010
# Epoch 5/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2719 - accuracy: 0.7318
# Epoch 5: val_loss improved from 0.81163 to 0.59567, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 104ms/step - loss: 0.2724 - accuracy: 0.7314 - val_loss: 0.5957 - val_accuracy: 0.5741 - lr: 1.0000e-04
# Epoch 6/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2651 - accuracy: 0.7329
# Epoch 6: val_loss improved from 0.59567 to 0.42788, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2649 - accuracy: 0.7330 - val_loss: 0.4279 - val_accuracy: 0.6544 - lr: 1.0000e-04
# Epoch 7/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2555 - accuracy: 0.7337
# Epoch 7: val_loss improved from 0.42788 to 0.33453, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 104ms/step - loss: 0.2561 - accuracy: 0.7334 - val_loss: 0.3345 - val_accuracy: 0.7055 - lr: 1.0000e-04
# Epoch 8/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.7343
# Epoch 8: val_loss improved from 0.33453 to 0.29542, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 104ms/step - loss: 0.2506 - accuracy: 0.7342 - val_loss: 0.2954 - val_accuracy: 0.7256 - lr: 1.0000e-04
# Epoch 9/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2449 - accuracy: 0.7351
# Epoch 9: val_loss improved from 0.29542 to 0.28479, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2450 - accuracy: 0.7348 - val_loss: 0.2848 - val_accuracy: 0.7266 - lr: 1.0000e-04
# Epoch 10/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2427 - accuracy: 0.7302
# Epoch 10: val_loss improved from 0.28479 to 0.27977, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2426 - accuracy: 0.7304 - val_loss: 0.2798 - val_accuracy: 0.7267 - lr: 1.0000e-04
# Epoch 11/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2411 - accuracy: 0.7350
# Epoch 11: val_loss improved from 0.27977 to 0.27069, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2409 - accuracy: 0.7351 - val_loss: 0.2707 - val_accuracy: 0.7305 - lr: 1.0000e-04
# Epoch 12/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2327 - accuracy: 0.7345
# Epoch 12: val_loss improved from 0.27069 to 0.26379, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2330 - accuracy: 0.7345 - val_loss: 0.2638 - val_accuracy: 0.7336 - lr: 1.0000e-04
# Epoch 13/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2334 - accuracy: 0.7352
# Epoch 13: val_loss improved from 0.26379 to 0.25957, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2336 - accuracy: 0.7347 - val_loss: 0.2596 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 14/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.7303
# Epoch 14: val_loss did not improve from 0.25957
# 56/56 [==============================] - 6s 100ms/step - loss: 0.2322 - accuracy: 0.7303 - val_loss: 0.2609 - val_accuracy: 0.7239 - lr: 1.0000e-04
# Epoch 15/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2261 - accuracy: 0.7340
# Epoch 15: val_loss did not improve from 0.25957
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2262 - accuracy: 0.7338 - val_loss: 0.2800 - val_accuracy: 0.7162 - lr: 1.0000e-04
# Epoch 16/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2216 - accuracy: 0.7348
# Epoch 16: val_loss improved from 0.25957 to 0.25934, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 106ms/step - loss: 0.2216 - accuracy: 0.7349 - val_loss: 0.2593 - val_accuracy: 0.7278 - lr: 1.0000e-04
# Epoch 17/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2200 - accuracy: 0.7364
# Epoch 17: val_loss did not improve from 0.25934
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2200 - accuracy: 0.7362 - val_loss: 0.2659 - val_accuracy: 0.7202 - lr: 1.0000e-04
# Epoch 18/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2140 - accuracy: 0.7344
# Epoch 18: val_loss improved from 0.25934 to 0.25862, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2138 - accuracy: 0.7347 - val_loss: 0.2586 - val_accuracy: 0.7223 - lr: 1.0000e-04
# Epoch 19/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2116 - accuracy: 0.7366
# Epoch 19: val_loss did not improve from 0.25862
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2118 - accuracy: 0.7364 - val_loss: 0.2669 - val_accuracy: 0.7178 - lr: 1.0000e-04
# Epoch 20/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2123 - accuracy: 0.7317
# Epoch 20: val_loss did not improve from 0.25862
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2123 - accuracy: 0.7319 - val_loss: 0.2855 - val_accuracy: 0.7043 - lr: 1.0000e-04
# Epoch 21/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2102 - accuracy: 0.7353
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 21: val_loss did not improve from 0.25862
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2100 - accuracy: 0.7356 - val_loss: 0.2590 - val_accuracy: 0.7239 - lr: 1.0000e-04
# Epoch 22/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2014 - accuracy: 0.7374
# Epoch 22: val_loss improved from 0.25862 to 0.25839, saving model to model-tgs-salt.h5
# 56/56 [==============================] - 6s 103ms/step - loss: 0.2013 - accuracy: 0.7375 - val_loss: 0.2584 - val_accuracy: 0.7222 - lr: 1.0000e-05
# Epoch 23/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2039 - accuracy: 0.7349
# Epoch 23: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2039 - accuracy: 0.7348 - val_loss: 0.2604 - val_accuracy: 0.7190 - lr: 1.0000e-05
# Epoch 24/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.7386
# Epoch 24: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.1931 - accuracy: 0.7383 - val_loss: 0.2619 - val_accuracy: 0.7176 - lr: 1.0000e-05
# Epoch 25/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1943 - accuracy: 0.7364
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 25: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 102ms/step - loss: 0.1949 - accuracy: 0.7363 - val_loss: 0.2626 - val_accuracy: 0.7160 - lr: 1.0000e-05
# Epoch 26/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1969 - accuracy: 0.7376
# Epoch 26: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.1972 - accuracy: 0.7373 - val_loss: 0.2643 - val_accuracy: 0.7160 - lr: 1.0000e-05
# Epoch 27/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.7372
# Epoch 27: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.1916 - accuracy: 0.7369 - val_loss: 0.2627 - val_accuracy: 0.7140 - lr: 1.0000e-05
# Epoch 28/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2013 - accuracy: 0.7329
# Epoch 28: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.2018 - accuracy: 0.7330 - val_loss: 0.2647 - val_accuracy: 0.7132 - lr: 1.0000e-05
# Epoch 29/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.7374
# Epoch 29: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.1952 - accuracy: 0.7376 - val_loss: 0.2660 - val_accuracy: 0.7146 - lr: 1.0000e-05
# Epoch 30/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1920 - accuracy: 0.7391
# Epoch 30: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.1922 - accuracy: 0.7386 - val_loss: 0.2631 - val_accuracy: 0.7153 - lr: 1.0000e-05
# Epoch 31/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1946 - accuracy: 0.7373
# Epoch 31: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 101ms/step - loss: 0.1945 - accuracy: 0.7373 - val_loss: 0.2672 - val_accuracy: 0.7123 - lr: 1.0000e-05
# Epoch 32/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.7363
# Epoch 32: val_loss did not improve from 0.25839
# 56/56 [==============================] - 6s 102ms/step - loss: 0.1914 - accuracy: 0.7363 - val_loss: 0.2648 - val_accuracy: 0.7129 - lr: 1.0000e-05
# Epoch 32: early stopping

# %%
model.save(WORK_DIR+'jac01.mod')
model.save(WORK_DIR+'bce01.mod')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.

# %%
model.load_weights(WORK_DIR+'jac01.mod')
# model.load_weights(WORK_DIR+'bce01.mod')

# %%
def plot_history(results):
    plt.figure(figsize=(8,8))
    plt.title("Loss Vs Epochs")
    plt.plot(results.history["loss"], label="loss")
    plt.plot(results.history["val_loss"], label="val_loss")
    plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
    plt.xlabel("Epochs")
    plt.ylabel("log_loss")
    plt.legend();

    
plot_history(results)

# %%
#Inference
#model.load_weights('model-unet-salt.h5')
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 7/7 [==============================] - 0s 36ms/step - loss: 0.6189 - accuracy: 0.7365
# [0.6188759803771973, 0.7364501953125]

# %%
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 56/56 [==============================] - 1s 26ms/step
# 7/7 [==============================] - 0s 24ms/step

# %%
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample_results(X, y, preds, binary_preds):
    ix = random.randint(0, len(X))
    
    has_mask = y[ix].max() > 0
    
    fig, ax = plt.subplots(1, 4, figsize=(20,10))
    ax[0].imshow(X[ix].squeeze(), cmap='gray')
    
    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Salt')
    
    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    ax[3].set_title('Salt Predicted Binary') ;

# %%
## Predictions on Training Set
plot_sample_results(X_train, y_train,preds_train,preds_train_t)

# %%
## Predictions on Training Set
plot_sample_results(X_train, y_train, preds_train, preds_train_t)

# %%
## Predictions on Training Set
plot_sample_results(X_train, y_train, preds_train, preds_train_t)

# %%
## Predictions on Test Set
plot_sample_results(X_valid, y_valid, preds_val, preds_val_t)
